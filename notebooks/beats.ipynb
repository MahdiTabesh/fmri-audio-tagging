# %%
import sys
import json
from tqdm import tqdm

import torchaudio
import torch

import matplotlib.pyplot as plt
import numpy as np

sys.path.append('beats_model/unilm/beats/')

import torch
from Tokenizers import TokenizersConfig, Tokenizers

# load the pre-trained checkpoints
checkpoint = torch.load('beats_model/Tokenizer_iter3_plus_AS2M.pt')

cfg = TokenizersConfig(checkpoint['cfg'])
BEATs_tokenizer = Tokenizers(cfg)
BEATs_tokenizer.load_state_dict(checkpoint['model']) #load weights
BEATs_tokenizer.eval()

# tokenize the audio and generate the labels
audio_input_16khz = torch.randn(1, 10000)
padding_mask = torch.zeros(1, 10000).bool()

labels = BEATs_tokenizer.extract_labels(audio_input_16khz, padding_mask=padding_mask) #tokenize random audio input
# Out:
# /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
import torch
from BEATs import BEATs, BEATsConfig

# load the pre-trained checkpoints
checkpoint = torch.load('beats_model/BEATs_iter3_plus_AS2M.pt')

cfg = BEATsConfig(checkpoint['cfg']) #config for model architecture
BEATs_model = BEATs(cfg)
BEATs_model.load_state_dict(checkpoint['model']) #load model weights
BEATs_model.eval()

# extract the the audio representation
audio_input_16khz = torch.randn(1, 10000)
padding_mask = torch.zeros(1, 10000).bool()

representation = BEATs_model.extract_features(audio_input_16khz, padding_mask=padding_mask)[0] #get final layer audio features from rand audio

# %%
#dont run for feature extraction
import torch
from BEATs import BEATs, BEATsConfig

# load the fine-tuned checkpoints
checkpoint = torch.load('beats_model/BEATs_iter3_plus_AS2M_finetuned_on_AS2M_cpt2.pt') #classification model

cfg = BEATsConfig(checkpoint['cfg'])
BEATs_model = BEATs(cfg)
BEATs_model.load_state_dict(checkpoint['model'])
BEATs_model.eval()

# predict the classification probability of each class
audio_input_16khz = torch.randn(3, 10000) #3 rand audios batch
padding_mask = torch.zeros(3, 10000).bool()

probs = BEATs_model.extract_features(audio_input_16khz, padding_mask=padding_mask)[0] #classification probs for each audio

#prints raw ids
for i, (top5_label_prob, top5_label_idx) in enumerate(zip(*probs.topk(k=5))): #top 5 predicted classes for eahc audio and probs
    top5_label = [checkpoint['label_dict'][label_idx.item()] for label_idx in top5_label_idx]#class names from label_dict
    print(f'Top 5 predicted labels of the {i}th audio are {top5_label} with probability of {top5_label_prob}')
# Out:
# Top 5 predicted labels of the 0th audio are ['/m/07rgkc5', '/m/0chx_', '/m/09x0r', '/m/096m7z', '/m/07qlf79'] with probability of tensor([0.2851, 0.1603, 0.1547, 0.1278, 0.0467], grad_fn=<UnbindBackward0>)
# Top 5 predicted labels of the 1th audio are ['/m/07rgkc5', '/m/09x0r', '/m/0chx_', '/m/096m7z', '/m/0cj0r'] with probability of tensor([0.2293, 0.2038, 0.1629, 0.1511, 0.0409], grad_fn=<UnbindBackward0>)
# Top 5 predicted labels of the 2th audio are ['/m/07rgkc5', '/m/0chx_', '/m/09x0r', '/m/096m7z', '/m/0cj0r'] with probability of tensor([0.2256, 0.1552, 0.1496, 0.0777, 0.0540], grad_fn=<UnbindBackward0>)

# %% [markdown]
# ## Sample on one Movie

# %%
# Load the audio file
waveform, sample_rate = torchaudio.load("7T_MOVIE1_CC1_v2.wav") #waveform = raw audio data tensor

# Resample if the sampling rate is not 16kHz
if sample_rate != 16000:
    resample_transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000) #beats uses 16khz sampling rate
    waveform = resample_transform(waveform)

# Convert to mono if necessary
if waveform.shape[0] > 1:
    waveform = waveform.mean(dim=0, keepdim=True) #1 channel
# Out:
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load the audio file
# ----> 2 waveform, sample_rate = torchaudio.load("7T_MOVIE1_CC1_v2.wav") #waveform = raw audio data tensor
#       4 # Resample if the sampling rate is not 16kHz
#       5 if sample_rate != 16000:
#
# File /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/torchaudio/_backend/utils.py:205, in get_load_func.<locals>.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     128 """Load audio data from source.
#     129
#     130 By default (``normalize=True``, ``channels_first=True``), this function returns Tensor with
#    (...)
#     202         `[channel, time]` else `[time, channel]`.
#     203 """
#     204 backend = dispatcher(uri, format, backend)
# --> 205 return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#
# File /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/torchaudio/_backend/soundfile.py:27, in SoundfileBackend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#      17 @staticmethod
#      18 def load(
#      19     uri: Union[BinaryIO, str, os.PathLike],
#    (...)
#      25     buffer_size: int = 4096,
#      26 ) -> Tuple[torch.Tensor, int]:
# ---> 27     return soundfile_backend.load(uri, frame_offset, num_frames, normalize, channels_first, format)
#
# File /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/torchaudio/_backend/soundfile_backend.py:221, in load(filepath, frame_offset, num_frames, normalize, channels_first, format)
#     139 @_requires_soundfile
#     140 def load(
#     141     filepath: str,
#    (...)
#     146     format: Optional[str] = None,
#     147 ) -> Tuple[torch.Tensor, int]:
#     148     """Load audio data from file.
#     149
#     150     Note:
#    (...)
#     219             `[channel, time]` else `[time, channel]`.
#     220     """
# --> 221     with soundfile.SoundFile(filepath, "r") as file_:
#     222         if file_.format != "WAV" or normalize:
#     223             dtype = "float32"
#
# File /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/soundfile.py:690, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     687 self._bitrate_mode = bitrate_mode
#     688 self._info = _create_info_struct(file, mode, samplerate, channels,
#     689                                  format, subtype, endian)
# --> 690 self._file = self._open(file, mode_int, closefd)
#     691 if set(mode).issuperset('r+') and self.seekable():
#     692     # Move write position to 0 (like in Python file objects)
#     693     self.seek(0)
#
# File /opt/conda/envs/pytorch-dev/lib/python3.10/site-packages/soundfile.py:1265, in SoundFile._open(self, file, mode_int, closefd)
#    1262 if file_ptr == _ffi.NULL:
#    1263     # get the actual error code
#    1264     err = _snd.sf_error(file_ptr)
# -> 1265     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1266 if mode_int == _snd.SFM_WRITE:
#    1267     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1268     # when opening a named pipe in SFM_WRITE mode.
#    1269     # See http://github.com/erikd/libsndfile/issues/77.
#    1270     self._info.frames = 0
#
# LibsndfileError: Error opening '7T_MOVIE1_CC1_v2.wav': System error.

# %%
# plot waveform
plt.figure(figsize=(15, 5))
plt.plot(waveform.t().numpy())
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
waveform.shape
# Split the audio into chunks of 5 seconds
chunk_duration = 5  # seconds
chunk_samples = chunk_duration * 16000  # number of samples in each chunk
chunk_step = 1 * 16000  # step size for each chunk -> 1 sec, 16000 samples - overlap
chunks = []
for start in range(0, waveform.shape[1], chunk_step):
    end = min(start + chunk_samples, waveform.shape[1]) #start at start, end at start+chunk_samples
    chunk = waveform[:, start:end]
    if chunk.shape[1] == chunk_samples:
        chunks.append(chunk)
    else:
        # Pad the last chunk with zeros if it's shorter than 10 seconds
        padding = torch.zeros(1, chunk_samples - chunk.shape[1])
        chunk = torch.cat((chunk, padding), dim=1)
        chunks.append(chunk)
chunks = torch.cat(chunks, dim=0)
chunks.shape #(num chunks, chunk samples)
# chunks = chunks.unsqueeze(0)  # Add batch dimension
print(chunks.shape)
# Create a padding mask for the chunks
padding_mask = torch.zeros(chunks.shape[0], chunks.shape[1]).bool()
# The padding mask is all zeros since we don't have any padding in this case
# Out:
# torch.Size([922, 80000])

# %%
# Example: using a BEATs model instance named `beat_model`
BEATs_model.eval()  # set the model to evaluation mode
with torch.no_grad():
    probs =  BEATs_model.extract_features(chunks, padding_mask=padding_mask)[0] #pass audio inpnut chunks thru model, class probs

# %%
probs.shape
# Out:
# torch.Size([922, 527])

# %%
# Load ontology json
with open('beats_model/ontology.json', 'r') as f:
    ontology = json.load(f) #maps raw ids to readable format

# %%
# Open subtitle.srt file to write
probs_keep = []
with open('subtitle.srt', 'w') as f:
    for i, (top5_label_prob, top5_label_idx) in enumerate(zip(*probs.topk(k=5))):#each chunk get top 5 label idx and probs
        top5_label = [checkpoint['label_dict'][label_idx.item()] for label_idx in top5_label_idx] #label idx -> raw id
        probs_keep.append(top5_label_prob)
        # Find ids in the ontology and get the corresponding labels
        top5_names = []
        for name in top5_label:
            name = [item['name'] for item in ontology if item['id'] == name]
            top5_names.append(name)
        print(f'{i*chunk_duration} ==> {(i+1)*chunk_duration} ::: Labels {top5_names}')
        f.write(f'{i+1}\n')
        # Write the start and end time of the chunk in 00:00:00,000 --> 00:00:00,000 format
        start_time = i * chunk_duration
        end_time = (i + 1) * chunk_duration
        start_time_str = f'{int(start_time // 3600):02}:{int((start_time % 3600) // 60):02}:{int(start_time % 60):02},000'
        end_time_str = f'{int(end_time // 3600):02}:{int((end_time % 3600) // 60):02}:{int(end_time % 60):02},000'
        f.write(f'{start_time_str} --> {end_time_str}\n')
        f.write(f'{top5_names}\n\n')

f.close()
# Out:
# 0 ==> 5 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 5 ==> 10 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 10 ==> 15 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 15 ==> 20 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 20 ==> 25 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 25 ==> 30 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 30 ==> 35 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 35 ==> 40 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 40 ==> 45 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 45 ==> 50 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 50 ==> 55 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 55 ==> 60 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 60 ==> 65 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 65 ==> 70 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 70 ==> 75 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 75 ==> 80 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
#
::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Bird vocalization, bird call, bird song']]
# 370 ==> 375 ::: Labels [['Music'], ['Speech'], ['Bird vocalization, bird call, bird song'], ['Bird'], ['Chirp, tweet']]
# 375 ==> 380 ::: Labels [['Music'], ['Speech'], ['Bird'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet']]
# 380 ==> 385 ::: Labels [['Music'], ['Speech'], ['Bird vocalization, bird call, bird song'], ['Bird'], ['Chirp, tweet']]
# 385 ==> 390 ::: Labels [['Music'], ['Speech'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet'], ['Bird']]
# 390 ==> 395 ::: Labels [['Speech'], ['Music'], ['Male speech, man speaking'], ['Insect'], ['Narration, monologue']]
# 395 ==> 400 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Sonar']]
# 400 ==> 405 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Buzz'], ['Male speech, man speaking']]
# 405 ==> 410 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Buzz']]
# 410 ==> 415 ::: Labels [['Insect'], ['Music'], ['Cricket'], ['Speech'], ['Buzz']]
# 415 ==> 420 ::: Labels [['Insect'], ['Music'], ['Cricket'], ['Speech'], ['Buzz']]
# 420 ==> 425 ::: Labels [['Insect'], ['Speech'], ['Music'], ['Cricket'], ['Buzz']]
# 425 ==> 430 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Buzz']]
# 430 ==> 435 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Buzz']]
# 435 ==> 440 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Environmental noise'], ['Cricket']]
# 440 ==> 445 ::: Labels [['Speech'], ['Music'], ['Sonar'], ['Electronic music'], ['Insect']]
# 445 ==> 450 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Environmental noise']]
# 450 ==> 455 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Environmental noise']]
# 455 ==> 460 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Environmental noise'], ['Cricket']]
# 460 ==> 465 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Environmental noise']]
# 465 ==> 470 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Environmental noise']]
# 470 ==> 475 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Chirp, tweet'], ['Environmental noise']]
# 475 ==> 480 ::: Labels [['Speech'], ['Music'], ['Groan'], ['Insect'], ['Bellow']]
# 480 ==> 485 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Groan'], ['Bellow']]
# 485 ==> 490 ::: Labels [['Speech'], ['Music'], ['Groan'], ['Insect'], ['Outside, rural or natural']]
# 490 ==> 495 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Groan'], ['Cricket']]
# 495 ==> 500 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Environmental noise'], ['Cricket']]
# 500 ==> 505 ::: Labels [['Insect'], ['Music'], ['Speech'], ['Cricket'], ['Environmental noise']]
# 505 ==> 510 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Environmental noise']]
# 510 ==> 515 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Bird']]
# 515 ==> 520 ::: Labels [['Cricket'], ['Insect'], ['Music'], ['Speech'], ['Bird vocalization, bird call, bird song']]
# 520 ==> 525 ::: Labels [['Music'], ['Speech'], ['Cricket'], ['Insect'], ['Bird vocalization, bird call, bird song']]
# 525 ==> 530 ::: Labels [['Cricket'], ['Speech'], ['Music'], ['Insect'], ['Outside, rural or natural']]
# 530 ==> 535 ::: Labels [['Insect'], ['Speech'], ['Cricket'], ['Music'], ['Rain']]
# 535 ==> 540 ::: Labels [['Speech'], ['Insect'], ['Cricket'], ['Music'], ['Rain']]
# 540 ==> 545 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Rain'], ['Cricket']]
# 545 ==> 550 ::: Labels [['Insect'], ['Music'], ['Cricket'], ['Rain'], ['Animal']]
# 550 ==> 555 ::: Labels [['Insect'], ['Cricket'], ['Music'], ['Environmental noise'], ['Animal']]
# 555 ==> 560 ::: Labels [['Music'], ['Animal'], ['Clip-clop'], ['Horse'], ['Insect']]
# 560 ==> 565 ::: Labels [['Music'], ['Environmental noise'], ['Insect'], ['Cricket'], ['Outside, rural or natural']]
# 565 ==> 570 ::: Labels [['Music'], ['Speech'], ['Insect'], ['
::: Labels [['Speech'], ['Music'], ['Insect'], ['Male speech, man speaking'], ['Radio']]
# 750 ==> 755 ::: Labels [['Speech'], ['Music'], ['Insect'], ['Cricket'], ['Male speech, man speaking']]
# 755 ==> 760 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Buzz']]
# 760 ==> 765 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 765 ==> 770 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 770 ==> 775 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Outside, rural or natural']]
# 775 ==> 780 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Bird vocalization, bird call, bird song']]
# 780 ==> 785 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 785 ==> 790 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Male speech, man speaking'], ['Cricket']]
# 790 ==> 795 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 795 ==> 800 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 800 ==> 805 ::: Labels [['Insect'], ['Cricket'], ['Music'], ['Speech'], ['Outside, rural or natural']]
# 805 ==> 810 ::: Labels [['Insect'], ['Music'], ['Speech'], ['Cricket'], ['Buzz']]
# 810 ==> 815 ::: Labels [['Insect'], ['Cricket'], ['Music'], ['Speech'], ['Buzz']]
# 815 ==> 820 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Buzz']]
# 820 ==> 825 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Hum']]
# 825 ==> 830 ::: Labels [['Music'], ['Hum'], ['Mains hum'], ['Sonar'], ['Insect']]
# 830 ==> 835 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Hum']]
# 835 ==> 840 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Hum']]
# 840 ==> 845 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Bird vocalization, bird call, bird song']]
# 845 ==> 850 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 850 ==> 855 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Male speech, man speaking']]
# 855 ==> 860 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Animal']]
# 860 ==> 865 ::: Labels [['Bird vocalization, bird call, bird song'], ['Music'], ['Chirp, tweet'], ['Cricket'], ['Bird']]
# 865 ==> 870 ::: Labels [['Music'], ['Bird vocalization, bird call, bird song'], ['Speech'], ['Chirp, tweet'], ['Bird']]
# 870 ==> 875 ::: Labels [['Speech'], ['Music'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet'], ['Bird']]
# 875 ==> 880 ::: Labels [['Cricket'], ['Music'], ['Insect'], ['Speech'], ['Bird vocalization, bird call, bird song']]
# 880 ==> 885 ::: Labels [['Insect'], ['Cricket'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet'], ['Music']]
# 885 ==> 890 ::: Labels [['Insect'], ['Cricket'], ['Music'], ['Speech'], ['Male speech, man speaking']]
# 890 ==> 895 ::: Labels [['Music'], ['Speech'], ['Insect'], ['Cricket'], ['Radio']]
# 895 ==> 900 ::: Labels [['Music'], ['Speech'], ['Sonar'], ['Electronic music'], ['Ping']]
# 900 ==> 905 ::: Labels [['Music'], ['Speech'], ['Sonar'], ['Insect'], ['Cricket']]
# 905 ==> 910 ::: Labels [['Music'], ['Speech'], ['Sonar'], ['Environmental noise'], ['Outside, rural or natural']]
# 910 ==> 915 ::: Labels [['Music'], ['Speech'], ['Sonar'], ['Singing bowl'], ['Environmental noise']]
# 915 ==> 920 ::: Labels [['Music'], ['Environmental noise'], ['Bird'], ['Bird vocalization, bird call, bird song'], ['Singing bowl']]
# 920 ==> 925 ::: Labels [['Music'], ['Environmental noise'], ['Chime'], ['Singing bowl'], ['Insect']]
# 925 ==> 930 ::: Labels [['Music'], ['Environmental noise'], ['Insect'], ['Cricket'], ['Outside, rural or natural']]
# 930 ==> 935 ::: Labels [['Music'], ['Environmental noise'], ['Insect'], ['Singing bowl'], ['Outside, rural or natural']]
# 935 ==> 940 ::: Labels [['Music'], ['Insect'], ['Environmental noise'], ['Cricket'], ['Outside, rural or natural']]
::: Labels [['Music'], ['Speech'], ['Musical instrument'], ['Guitar'], ['Chirp, tweet']]
# 1515 ==> 1520 ::: Labels [['Music'], ['Speech'], ['Musical instrument'], ['Guitar'], ['Plucked string instrument']]
# 1520 ==> 1525 ::: Labels [['Music'], ['Speech'], ['Musical instrument'], ['Plucked string instrument'], ['Guitar']]
# 1525 ==> 1530 ::: Labels [['Music'], ['Speech'], ['Musical instrument'], ['Harp'], ['Pizzicato']]
# 1530 ==> 1535 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Musical instrument'], ['Bowed string instrument']]
# 1535 ==> 1540 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Bird vocalization, bird call, bird song'], ['Violin, fiddle']]
# 1540 ==> 1545 ::: Labels [['Music'], ['Speech'], ['Chirp, tweet'], ['Bird vocalization, bird call, bird song'], ['Animal']]
# 1545 ==> 1550 ::: Labels [['Music'], ['Speech'], ['Bird'], ['Animal'], ['Bird vocalization, bird call, bird song']]
# 1550 ==> 1555 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Bird'], ['Bird vocalization, bird call, bird song']]
# 1555 ==> 1560 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Bird vocalization, bird call, bird song'], ['Bird']]
# 1560 ==> 1565 ::: Labels [['Music'], ['Speech'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet'], ['Bird']]
# 1565 ==> 1570 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Bird vocalization, bird call, bird song'], ['Fowl']]
# 1570 ==> 1575 ::: Labels [['Music'], ['Speech'], ['Animal'], ['Bird vocalization, bird call, bird song'], ['Fowl']]
# 1575 ==> 1580 ::: Labels [['Music'], ['Speech'], ['New-age music'], ['Animal'], ['Female speech, woman speaking']]
# 1580 ==> 1585 ::: Labels [['Music'], ['Speech'], ['New-age music'], ['Animal'], ['Female speech, woman speaking']]
# 1585 ==> 1590 ::: Labels [['Music'], ['Speech'], ['Female speech, woman speaking'], ['New-age music'], ['Animal']]
# 1590 ==> 1595 ::: Labels [['Music'], ['Speech'], ['Female speech, woman speaking'], ['Chirp, tweet'], ['Harp']]
# 1595 ==> 1600 ::: Labels [['Music'], ['Speech'], ['Chirp, tweet'], ['Bird vocalization, bird call, bird song'], ['Bird']]
# 1600 ==> 1605 ::: Labels [['Music'], ['Speech'], ['Chirp, tweet'], ['Bird vocalization, bird call, bird song'], ['Bird']]
# 1605 ==> 1610 ::: Labels [['Music'], ['Guitar'], ['Flamenco'], ['Musical instrument'], ['Bird vocalization, bird call, bird song']]
# 1610 ==> 1615 ::: Labels [['Music'], ['Guitar'], ['Musical instrument'], ['Plucked string instrument'], ['New-age music']]
# 1615 ==> 1620 ::: Labels [['Music'], ['Bird'], ['Bird vocalization, bird call, bird song'], ['Chirp, tweet'], ['New-age music']]
# 1620 ==> 1625 ::: Labels [['Music'], ['Guitar'], ['Musical instrument'], ['Plucked string instrument'], ['Acoustic guitar']]
# 1625 ==> 1630 ::: Labels [['Music'], ['Guitar'], ['Acoustic guitar'], ['Musical instrument'], ['Plucked string instrument']]
# 1630 ==> 1635 ::: Labels [['Music'], ['New-age music'], ['Acoustic guitar'], ['Guitar'], ['Plucked string instrument']]
::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]
# 4605 ==> 4610 ::: Labels [['Music'], ['Vehicle'], ['Speech'], ['Car'], ['Boat, Water vehicle']]

# %%
plt.figure(figsize=(15, 5))
plt.plot(np.array(probs_keep)[:,[0,1]])
# plt.plot(np.max(probs_keep, axis=1))
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Probability")

# Higlight fixation points
# Fixation = [10:21+10 265:285+10 506:526+10 714:734+10 798:818+10 901:921];
fixation = [10, 21, 265, 285, 506, 526, 714, 734, 798, 818, 901, 921] #highlighted sections start and end idxs
for i in range(0,len(fixation),2):
    plt.axvspan(fixation[i], fixation[i+1], color='red', alpha=0.5)

#plot highest and 2nd highest class confidence
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(np.array(probs_keep)[:,[0,1]])
# plt.plot(np.max(probs_keep, axis=1))
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Probability")

# Higlight fixation points
# Fixation = [10:21+10 265:285+10 506:526+10 714:734+10 798:818+10 901:921];
fixation = [10, 21, 265, 285, 506, 526, 714, 734, 798, 818, 901, 921]
for i in range(0,len(fixation),2):
    plt.axvspan(fixation[i], fixation[i+1], color='red', alpha=0.5)
plt.show()

# %% [markdown]
# ## Label All 4 Movies

# %%
Names = ['7T_MOVIE1_CC1_v2', '7T_MOVIE2_HO1_v2', '7T_MOVIE3_CC2_v2', '7T_MOVIE4_HO2_v2']
Time = [0, 921, 921+918, 921+918+915, 921+918+915+901]
chunk_duration = 1  # seconds
chunk_samples = chunk_duration * 16000  # number of samples in each chunk
chunk_step = 1 * 16000  # step size for each chunk
threshold = 0.25;

with open('beats_model/ontology.json', 'r') as f:
    ontology = json.load(f)

with open(f'subtitle_merged.srt', 'w') as f_m:
    probs_keep_all = []
    top5_names_all = []
    for iter_num, name in tqdm(enumerate(Names)):
        # Load the audio file
        waveform, sample_rate = torchaudio.load(f"{name}.wav")

        # Resample if the sampling rate is not 16kHz
        if sample_rate != 16000:
            resample_transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
            waveform = resample_transform(waveform)

        # Convert to mono if necessary
        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)

        # Split the audio into chunks
        chunks = []
        for start in range(0, waveform.shape[1], chunk_step):
            end = min(start + chunk_samples, waveform.shape[1])
            chunk = waveform[:, start:end]
            if chunk.shape[1] == chunk_samples:
                chunks.append(chunk)
            else:
                # Pad the last chunk with zeros if it's shorter than 10 seconds
                padding = torch.zeros(1, chunk_samples - chunk.shape[1])
                chunk = torch.cat((chunk, padding), dim=1)
                # chunks.append(chunk)
        chunks = torch.cat(chunks, dim=0)
        padding_mask = torch.zeros(chunks.shape[0], chunks.shape[1]).bool()

        BEATs_model.eval()  # set the model to evaluation mode
        with torch.no_grad():
            probs =  BEATs_model.extract_features(chunks, padding_mask=padding_mask)[0]

        # Open subtitle.srt file to write
        probs_keep = []
        top5_keep = []
        with open(f'{name}.srt', 'w') as f:
            for i, (top5_label_prob, top5_label_idx) in tqdm(enumerate(zip(*probs.topk(k=5)))):
                top5_label = [checkpoint['label_dict'][label_idx.item()] for label_idx in top5_label_idx]
                probs_keep.append(top5_label_prob)
                # Find ids in the ontology and get the corresponding labels
                top5_names = []
                for ind, name in enumerate(top5_label):
                    if top5_label_prob[ind] < threshold:
                        continue
                    name = [item['name'] for item in ontology if item['id'] == name]
                    top5_names.append(name)
                # print(f'{i*chunk_duration} ==> {(i+1)*chunk_duration} ::: Labels {top5_names}')
                top5_keep.append(top5_names)
                f.write(f'{i+1}\n')
                # Write the start and end time of the chunk in 00:00:00,000 --> 00:00:00,000 format
                start_time = i * chunk_duration
                end_time = (i + 1) * chunk_duration
                start_time_str = f'{int(start_time // 3600):02}:{int((start_time % 3600) // 60):02}:{int(start_time % 60):02},000'
                end_time_str = f'{int(end_time // 3600):02}:{int((end_time % 3600) // 60):02}:{int(end_time % 60):02},000'
                f.write(f'{start_time_str} --> {end_time_str}\n')
                f.write(f'{top5_names}\n\n')

                f_m.write(f'{i+Time[iter_num]+1}\n')
                start_time = start_time + Time[iter_num]
                end_time = end_time + Time[iter_num]
                start_time_str = f'{int(start_time // 3600):02}:{int((start_time % 3600) // 60):02}:{int(start_time % 60):02},000'
                end_time_str = f'{int(end_time // 3600):02}:{int((end_time % 3600) // 60):02}:{int(end_time % 60):02},000'
                f_m.write(f'{start_time_str} --> {end_time_str}\n')
                f_m.write(f'{top5_names}\n\n')

        f.close()
        probs_keep_all.append(probs_keep)
        top5_names_all.append(top5_keep)
f_m.close()
# Out:
# 921it [00:00, 24955.29it/s]
# 918it [00:00, 26465.94it/s]
# 915it [00:00, 26196.15it/s]
# 901it [00:00, 26099.98it/s]
# 4it [00:34,  8.68s/it]

# %%
# Fixation = [10:21+10 265:285+10 506:526+10 714:734+10 798:818+10 901:921 921+[1:21+10 247:267+10 526:546+10 795:815+10 898:918] ...
#             921+918+[1:21+10 201:221+10 406:426+10 630:650+10 792:812+10 895:915] 921+918+915+[1:21+10 253:273+10 503:523+10 778:798+10 881:901]];
fixation = [10, 21, 265, 285, 506, 526, 714, 734, 798, 818, 901, 921,
            921+1, 921+21, 921+247, 921+267, 921+526, 921+546, 921+795, 921+815, 921+898, 921+918,
            921+918+1, 921+918+21, 921+918+201, 921+918+221, 921+918+406, 921+918+426, 921+918+630, 921+918+650,
            921+918+792, 921+918+812, 921+918+895, 921+918+915,
            921+918+915+1, 921+918+915+21, 921+918+915+253, 921+918+915+273, 921+918+915+503, 921+918+915+523,
            921+918+915+778, 921+918+915+798, 921+918+915+881, 921+918+915+901]

max(fixation)
# Out:
# 3655

# %%
probs_keep_all = probs_keep_all[0] + probs_keep_all[1] + probs_keep_all[2] + probs_keep_all[3]
len(probs_keep_all)
# Out:
# 3655

# %%
top5_names_all = top5_names_all[0] + top5_names_all[1] + top5_names_all[2] + top5_names_all[3]
len(top5_names_all)
# Out:
# 3655

# %%
# plot probs_keep_all
plt.figure(figsize=(15, 5))
plt.plot(np.array(probs_keep_all)[:,:])
# plt.plot(np.max(probs_keep, axis=1))
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Probability")
# Higlight fixation points
for i in range(0,len(fixation),2):
    plt.axvspan(fixation[i], fixation[i+1], color='red', alpha=0.5)
plt.show()

# %%
top5_names_all[0]
# Out:
# []

# %%
# plot probs_keep_all
plt.figure(figsize=(15, 5))
plt.plot([['Music'] in item for item in top5_names_all])
# plt.plot([['Speech'] in item for item in top5_names_all])
# plt.plot(np.max(probs_keep, axis=1))
plt.title("Audio Waveform")
plt.xlabel("Time")
plt.ylabel("Probability")
plt.legend(['Music', 'Speech'])
# Higlight fixation points
for i in range(0,len(fixation),2):
    plt.axvspan(fixation[i], fixation[i+1], color='red', alpha=0.5)
plt.show()

# %%
print(f"music/all: {sum([['Music'] in item for item in top5_names_all])/len(top5_names_all)}")
print(f"speech/all: {sum([['Speech'] in item for item in top5_names_all])/len(top5_names_all)}")
# Out:
# music/all: 0.5611491108071135
# speech/all: 0.5436388508891928

# %%
# save regressor to .mat file
import scipy.io as sio
probs_keep_all = np.array(probs_keep_all)
sio.savemat('probs_keep_all.mat', {'probs_keep_all': probs_keep_all})

# %%
# Convert top5_names_all to a cell structure for matlab
top5_names_all_cell = []
for item in top5_names_all:
    # print(item)
    if len(item) == 0:
        top5_names_all_cell.append(np.array('', dtype=object))
    else:
        top5_names_all_cell.append(np.array(item))
top5_names_all_cell = np.array(top5_names_all_cell, dtype=object)
sio.savemat('top5_names_all_cell.mat', {'top5_names_all_cell': top5_names_all_cell})

# %%
for i in top5_names_all_cell:
    print(i)
# Out:
# [['Insect']
#  ['Cricket']]
# [['Insect']]
# [['Music']]
#
# [['Insect']
#  ['Cricket']]
# [['Insect']
#  ['Cricket']]
# [['Insect']]
# [['Music']]
# [['Insect']
#  ['Cricket']]
# [['Insect']
#  ['Cricket']]
# [['Cricket']
#  ['Insect']]
# [['Cricket']
#  ['Insect']]
# [['Insect']
#  ['Cricket']]
# [['Cricket']
#  ['Insect']]
# [['Cricket']
#  ['Insect']]
# [['Insect']
#  ['Cricket']
#  ['Environmental noise']]
# [['Insect']
#  ['Cricket']]
# [['Cricket']
#  ['Insect']
#  ['Fly, housefly']]
# [['Insect']
#  ['Cricket']
#  ['Fly, housefly']
#  ['Mosquito']]
# [['Insect']
#  ['Cricket']
#  ['Fly, housefly']
#  ['Bee, wasp, etc.']]
# [['Insect']
#  ['Cricket']]
# [['Music']]
# [['Music']]
# [['Cricket']
#  ['Music']
#  ['Insect']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Insect']
#  ['Cricket']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Sonar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Cricket']
#  ['Insect']]
# [['Music']]
# [['Music']
#  ['Insect']]
# [['Music']
#  ['Insect']
#  ['Cricket']]
# [['Music']]
# [['Music']
#  ['Insect']]
# [['Insect']
#  ['Cricket']
#  ['Music']]
# [['Music']
#  ['Insect']
#  ['Cricket']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Insect']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Bird']
#  ['Bird vocalization, bird call, bird song']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Insect']
#  ['Cricket']]
# [['Music']]
# [['Music']
#  ['Bird']
#  ['Chirp, tweet']
#  ['Bird vocalization, bird call, bird song']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']
#  ['Insect']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Buzz']]
# [['Music']
#  ['Speech']
#  ['Insect']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Rain']]
# [['Music']]
# [['Speech']
#  ['Music']
#  ['Insect']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Chime']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Insect']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Insect']
#  ['Cricket']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Ratchet, pawl']
#  ['Gears']
#  ['Music']
#  ['Mechanisms']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']]
# [['Speech']
#  ['Insect']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Cricket']
#  ['Insect']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']]
# [['Insect']
#  ['Cricket']
#  ['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Bird vocalization, bird call, bird song']
#  ['Chirp, tweet']
#  ['Bird']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Insect']]
# [['Speech']]
# [['Music']
#  ['Speech']
#  ['Sonar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Insect']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Insect']]
# [['Music']]
# [['Music']
#  ['Rain']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
#
# [['Music']]
# [['Music']]
# [['Insect']
#  ['Music']]
# [['Music']]
#
#
#
#
#
# [['Insect']]
#
#
#
# [['Rain']]
#
#
#
#
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Percussion']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Flamenco']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Bird vocalization, bird call, bird song']
#  ['Chirp, tweet']]
#
# [['Environmental noise']]
# [['Environmental noise']]
# [['Speech']
#  ['Bird vocalization, bird call, bird song']
#  ['Chirp, tweet']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
#
#
# [['Music']]
# [['Speech']]
# [['Music']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Ukulele']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Effects unit']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Flamenco']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Music']
#  ['Speech']
#  ['Mandolin']
#  ['Musical instrument']
#  ['Plucked string instrument']]
# [['Music']
#  ['Mandolin']]
# [['Music']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Guitar']]
# [['Music']
#  ['Mandolin']
#  ['Musical instrument']]
# [['Music']
#  ['Mandolin']
#  ['Musical instrument']]
# [['Music']
#  ['Mandolin']
#  ['Musical instrument']
#  ['Ukulele']
#  ['Guitar']]
# [['Music']
#  ['Ukulele']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Mandolin']
#  ['Singing']]
# [['Music']
#  ['Ukulele']
#  ['Inside, small room']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']
#  ['Mandolin']
#  ['Ukulele']
#  ['Speech']]
# [['Music']
#  ['Ukulele']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']
#  ['Ukulele']]
# [['Music']
#  ['Singing']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Country']
#  ['Guitar']
#  ['Mandolin']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Female speech, woman speaking']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Humming']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Speech']
#  ['Singing bowl']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Foghorn']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Chewing, mastication']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Brass instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Mantra']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Mantra']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Whale vocalization']]
#
# [['Whale vocalization']]
#
# [['Music']]
# [['Music']]
#
# [['Speech']]
#
# [['Speech']]
#
# [['Speech']]
# [['Music']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
#
# [['Music']
#  ['Speech']]
#
#
# [['Speech']]
# [['Speech']
#  ['Artillery fire']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Sidetone']]
# [['Heart sounds, heartbeat']
#  ['Music']
#  ['Throbbing']
#  ['Heart murmur']
#  ['Hum']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']
#  ['Speech']]
#
#
# [['Music']]
# [['Music']
#  ['Cello']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Cello']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Steel guitar, slide guitar']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Effects unit']
#  ['Plucked string instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Effects unit']]
# [['Music']]
# [['Music']
#  ['Steel guitar, slide guitar']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Zipper (clothing)']]
# [['Music']
#  ['Squeal']
#  ['Rub']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Computer keyboard']
#  ['Typing']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']
#  ['Bowed string instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Musical instrument']
#  ['Violin, fiddle']]
# [['Music']
#  ['Musical instrument']
#  ['Violin, fiddle']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Marimba, xylophone']
#  ['Glockenspiel']
#  ['Mallet percussion']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Sheep']
#  ['Bleat']]
# [['Music']
#  ['Water']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Scary music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Scary music']]
# [['Music']]
# [['Music']]
# [['Train']
#  ['Speech']]
# [['Music']]
# [['Train']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Scary music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
#
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Rumble']
#  ['Whale vocalization']]
# [['Music']
#  ['Speech']
#  ['Scary music']]
# [['Music']
#  ['Scary music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Scary music']]
# [['Music']]
# [['Music']
#  ['Scary music']]
# [['Music']]
# [['Music']]
# [['Music']]
#
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
#
#
# [['Speech']]
#
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']
#  ['Scary music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Shatter']
#  ['Chink, clink']]
# [['Wind chime']
#  ['Chime']]
# [['Chime']
#  ['Wind chime']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Animal']]
# [['Speech']]
# [['Honk']
#  ['Goose']
#  ['Fowl']]
# [['Speech']
#  ['Run']]
# [['Speech']]
# [['Bird flight, flapping wings']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Boat, Water vehicle']
#  ['Vehicle']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Boat, Water vehicle']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Boat, Water vehicle']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Chink, clink']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Chink, clink']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Chink, clink']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Pulleys']]
# [['Speech']
#  ['Pulleys']
#  ['Mechanisms']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Chink, clink']]
# [['Speech']
#  ['Wind chime']
#  ['Chime']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Female speech, woman speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Narration, monologue']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Outside, urban or manmade']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Music']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Narration, monologue']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Music']
#  ['Narration, monologue']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Speech']
#  ['Whispering']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']]
#
# [['Stomach rumble']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Animal']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Cricket']]
# [['Speech']]
# [['Speech']]
#
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
# [['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Computer keyboard']
#  ['Speech']
#  ['Typing']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
#
#
# [['Speech']]
# [['Speech']]
# [['Music']]
#
#
# [['Speech']]
#
# [['Speech']]
#
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']
#  ['Speech']]
#
#
# [['Music']]
# [['Music']
#  ['Cello']
#  ['Musical instrument']]
# [['Music']
#  ['Cello']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Steel guitar, slide guitar']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Effects unit']
#  ['Plucked string instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Effects unit']]
# [['Music']]
# [['Music']
#  ['Steel guitar, slide guitar']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Zipper (clothing)']
#  ['Squeal']
#  ['Speech']]
# [['Music']
#  ['Rub']
#  ['Squeal']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Computer keyboard']
#  ['Typing']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']
#  ['Bowed string instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Musical instrument']
#  ['Violin, fiddle']]
# [['Music']
#  ['Musical instrument']
#  ['Violin, fiddle']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Glockenspiel']
#  ['Marimba, xylophone']
#  ['Mallet percussion']]
# [['Music']
#  ['Glockenspiel']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Water']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Music']
#  ['Guitar']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Lullaby']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Country']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']
#  ['Silence']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']]
# [['Music']]
# [['Music']
#  ['Singing']
#  ['Gospel music']
#  ['Christian music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Country']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Country']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Christian music']
#  ['Mantra']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Ringtone']]
# [['Music']
#  ['Ringtone']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Country']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Country']
#  ['Bluegrass']]
# [['Music']
#  ['Singing']
#  ['Gospel music']
#  ['Country']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']
#  ['Country']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Country']
#  ['Bluegrass']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Christian music']]
# [['Music']]
# [['Music']
#  ['Gospel music']
#  ['Singing']
#  ['Christian music']
#  ['Choir']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']]
# [['Music']
#  ['Gospel music']
#  ['Christian music']
#  ['Singing']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']
#  ['Gospel music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing']
#  ['Gospel music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']]
# [['Speech']]
#
# [['Vehicle']
#  ['Fixed-wing aircraft, airplane']
#  ['Aircraft']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
#
#
#
#
#
#
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Music']]
#
# [['Speech']]
#
# [['Speech']]
#
#
#
# [['Speech']]
# [['Music']]
# [['Music']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
#
# [['Speech']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Piano']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Musical instrument']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Scissors']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Mechanisms']]
# [['Speech']]
# [['Speech']]
# [['Mechanisms']]
# [['Music']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Piano']]
# [['Music']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Piano']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Piano']]
# [['Music']
#  ['Piano']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Marimba, xylophone']]
# [['Music']
#  ['Musical instrument']]
# [['Music']
#  ['Piano']
#  ['Musical instrument']]
# [['Music']
#  ['Pizzicato']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Piano']]
# [['Music']
#  ['Piano']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Piano']]
# [['Music']
#  ['Piano']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Alarm clock']
#  ['Alarm']
#  ['Music']]
# [['Alarm clock']
#  ['Alarm']
#  ['Speech']]
# [['Alarm clock']
#  ['Music']
#  ['Alarm']]
# [['Alarm clock']
#  ['Music']
#  ['Alarm']]
# [['Alarm clock']
#  ['Music']
#  ['Alarm']]
# [['Alarm clock']]
# [['Alarm clock']
#  ['Alarm']
#  ['Speech']]
# [['Alarm clock']
#  ['Alarm']
#  ['Speech']]
# [['Alarm clock']
#  ['Alarm']]
# [['Speech']
#  ['Alarm clock']]
# [['Alarm clock']
#  ['Alarm']
#  ['Music']
#  ['Speech']]
# [['Alarm clock']
#  ['Alarm']
#  ['Speech']]
# [['Alarm clock']
#  ['Alarm']
#  ['Speech']
#  ['Music']]
# [['Mechanisms']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Ukulele']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Ding']]
# [['Music']
#  ['Ukulele']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Ding']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']
#  ['Ukulele']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Ukulele']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Music']
#  ['Speech']
#  ['Banjo']
#  ['Bluegrass']
#  ['Country']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Ukulele']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']
#  ['Female speech, woman speaking']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Bluegrass']
#  ['Musical instrument']
#  ['Banjo']
#  ['Country']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Jingle, tinkle']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Effects unit']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Sonar']
#  ['Speech']]
# [['Sonar']]
# [['Music']]
# [['Music']
#  ['Sonar']]
# [['Sonar']
#  ['Music']]
# [['Sonar']
#  ['Music']]
# [['Sonar']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Sonar']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Sonar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Singing bowl']
#  ['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Vehicle']
#  ['Aircraft']
#  ['Fixed-wing aircraft, airplane']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Mantra']
#  ['Music']
#  ['Chant']]
# [['Music']
#  ['Mantra']]
# [['Music']
#  ['Mantra']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Singing bowl']
#  ['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Mantra']
#  ['Singing bowl']
#  ['Chant']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']
#  ['Singing bowl']
#  ['Mantra']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Mantra']
#  ['Chant']]
# [['Music']
#  ['Mantra']
#  ['Chant']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Sonar']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Singing bowl']]
# [['Music']
#  ['Sonar']]
# [['Music']]
# [['Music']]
# [['Singing bowl']
#  ['Music']]
# [['Singing bowl']
#  ['Music']]
# [['Singing bowl']
#  ['Music']]
# ...
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Scissors']]
# [['Speech']
#  ['Scissors']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Synthetic singing']
#  ['Speech']]
# [['Music']
#  ['Synthetic singing']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Narration, monologue']
#  ['Female speech, woman speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Child speech, kid speaking']]
# [['Speech']]
# [['Thunder']
#  ['Thunderstorm']]
# [['Thunder']
#  ['Thunderstorm']
#  ['Rain']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Chink, clink']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Whispering']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Child speech, kid speaking']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
#
# [['Music']
#  ['Speech']
#  ['Child singing']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Scary music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']]
# [['Speech']
#  ['Animal']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
#
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Whispering']]
# [['Vehicle']
#  ['Music']
#  ['Car']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Television']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Scissors']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Harp']]
# [['Music']
#  ['Harp']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']
#  ['Animal']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Animal']
#  ['Speech']]
# [['Bird']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
#
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Chirp, tweet']]
# [['Music']]
# [['Speech']]
#
# [['Speech']]
# [['Speech']
#  ['Chirp, tweet']]
# [['Speech']]
# [['Speech']
#  ['Chirp, tweet']]
# [['Speech']
#  ['Bird']]
# [['Chicken, rooster']
#  ['Bird']]
# [['Speech']]
#
# [['Chicken, rooster']
#  ['Bird']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Narration, monologue']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Female speech, woman speaking']]
# [['Speech']]
# [['Speech']
#  ['Female speech, woman speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Child speech, kid speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Tearing']
#  ['Speech']
#  ['Crumpling, crinkling']]
# [['Bird']
#  ['Pigeon, dove']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Bird']
#  ['Pigeon, dove']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']
#  ['Bird']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Television']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Television']]
# [['Music']
#  ['Scary music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
#
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
#
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
#
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Television']
#  ['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
#
#
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Wild animals']
#  ['Animal']]
# [['Insect']
#  ['Fly, housefly']
#  ['Speech']
#  ['Mosquito']
#  ['Buzz']]
# [['Speech']
#  ['Vehicle']]
# [['Speech']]
# [['Goose']
#  ['Fowl']
#  ['Honk']]
# [['Speech']]
# [['Mosquito']
#  ['Fly, housefly']
#  ['Insect']]
# [['Frog']]
#
#
# [['Speech']]
# [['Speech']]
# [['Music']]
# [['Speech']]
# [['Speech']
#  ['Cattle, bovinae']
#  ['Moo']
#  ['Livestock, farm animals, working animals']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Animal']
#  ['Cat']
#  ['Domestic animals, pets']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Cattle, bovinae']
#  ['Moo']]
# [['Speech']]
#
# [['Speech']
#  ['Scissors']]
# [['Speech']]
# [['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Bowed string instrument']
#  ['Cello']
#  ['Musical instrument']]
# [['Speech']]
# [['Mouse']]
#
# [['Speech']]
# [['Music']]
#
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']
#  ['Scissors']
#  ['Music']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Speech']]
# [['Music']]
#
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Bird']
#  ['Pigeon, dove']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']]
# [['Speech']
#  ['Male speech, man speaking']
#  ['Narration, monologue']]
# [['Speech']]
# [['Speech']]
# [['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']]
# [['Music']]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# [['Music']
#  ['Speech']]
#
#
# [['Music']]
# [['Music']
#  ['Cello']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Cello']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Plucked string instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Guitar']
#  ['Steel guitar, slide guitar']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Effects unit']
#  ['Plucked string instrument']]
# [['Music']
#  ['Guitar']
#  ['Musical instrument']
#  ['Plucked string instrument']
#  ['Effects unit']]
# [['Music']]
# [['Music']
#  ['Steel guitar, slide guitar']
#  ['Musical instrument']
#  ['Guitar']]
# [['Music']
#  ['Zipper (clothing)']
#  ['Squeal']]
# [['Music']
#  ['Rub']
#  ['Squeal']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Computer keyboard']
#  ['Typing']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']]
# [['Music']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Speech']
#  ['Music']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']
#  ['Bowed string instrument']]
# [['Speech']
#  ['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']
#  ['Male speech, man speaking']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']
#  ['Musical instrument']
#  ['Violin, fiddle']]
# [['Music']
#  ['Speech']
#  ['Violin, fiddle']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Violin, fiddle']
#  ['Musical instrument']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Marimba, xylophone']
#  ['Glockenspiel']
#  ['Mallet percussion']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Speech']
#  ['Music']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']
#  ['Water']]
# [['Music']
#  ['Speech']]
# [['Music']
#  ['Speech']]
# [['Music']]
# [['Music']]

# %% [markdown]
# ## Merge Subtitles

# %%
# Metge subtitles
file_names = ['7T_MOVIE1_CC1_v2', '7T_MOVIE2_HO1_v2', '7T_MOVIE3_CC2_v2', '7T_MOVIE4_HO2_v2']

with open('subtitle.srt', 'w') as f:
    for file_name in file_names:
        with open(f'{file_name}.srt', 'r') as f2:
            for line in f2:
                f.write(line)
        f.write('\n')
f.close()

# %% [markdown]
# # Feature Extraction on Movie

# %%
#only run once
import os
os.system("ffmpeg -i movie.mp4 -ar 16000 -ac 1 rest_audio.wav")
# Out:
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-2)
#   configuration: --prefix=/opt/conda/envs/pytorch-dev --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1743376049581/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1743376049581/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1743376049581/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1743376049581/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-alsa --enable-libpulse --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1743376049581/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'movie.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 01:00:55.00, start: 0.000000, bitrate: 12448 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1024x720, 12268 kb/s, 24 fps, 24 tbr, 19200 tbn (default)
#       Metadata:
#         handler_name    : Apple Video Media Handler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 173 kb/s (default)
#       Metadata:
#         handler_name    : Apple Sound Media Handler
#         vendor_id       : [0][0][0][0]
# File 'rest_audio.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# Error opening output file rest_audio.wav.
# 0

# %%
waveform, sample_rate = torchaudio.load("rest_audio.wav")
# Resample if the sampling rate is not 16kHz
if sample_rate != 16000:
    resample_transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000) #beats uses 16khz sampling rate
    waveform = resample_transform(waveform)

# Convert to mono if necessary
if waveform.shape[0] > 1:
    waveform = waveform.mean(dim=0, keepdim=True) #1 channel

# %%
print(waveform.shape, sample_rate)
# Out:
# torch.Size([1, 58480478]) 16000

# %%
#padding_mask = torch.zeros(waveform.shape).bool()#no padding mask
import torchaudio
import json
from tqdm import tqdm

chunk_samples = 16000*10 #10 second chunks -> run beats on each chunk individually to not crash
if sample_rate != 16000:
    resample_transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
    waveform = resample_transform(waveform)

if waveform.shape[0] > 1:
    waveform = waveform.mean(dim=0, keepdim=True)
    
device = torch.device("cuda")
BEATs_tokenizer = BEATs_tokenizer.to(device)
BEATs_model = BEATs_model.to(device)


labels = []
features = []
num_chunks = waveform.shape[1]//chunk_samples
BEATs_tokenizer.eval()
BEATs_model.eval()
with torch.no_grad():
    for start in tqdm(range(0, waveform.shape[1], chunk_samples), total=num_chunks):
        end = min(start + chunk_samples, waveform.shape[1])
        chunk = waveform[:, start:end]
        if chunk.shape[1] < chunk_samples:
            padding = torch.zeros(1, chunk_samples - chunk.shape[1], device=chunk.device)
            chunk = torch.cat((chunk, padding), dim=1)#zero padding if chunk too short
        chunk = chunk.to(device)
        labels_chunk = BEATs_tokenizer.extract_labels(chunk)
        labels.append(labels_chunk)
        features_chunk = BEATs_model.extract_features(chunk)[0]#(batch, num frames, frame dim)
        features.append(features_chunk.cpu().squeeze(0)) 

labels = torch.cat(labels, dim=0) #(token ids, )
features = torch.cat(features, dim=0)#(total frames, frame dim)

total_audio_dur = waveform.shape[1]/16000#num samples / sample rate
frame_rate = int(features.shape[0]/total_audio_dur)
print(frame_rate)

features_per_sec = []
for t in range(1, 3656):
    start = (t-1)*frame_rate #t-1 to t features
    end = t*frame_rate
    if end <= features.shape[0]:
        window = features[start:end]
        features_per_sec.append(window.mean(dim=0))#brain data 1 per sec -> 49 frames per sec feature vectors -> avg 49 feature vectors

features_per_sec = torch.stack(features_per_sec) #(time dim 3655, frame dim -> num features)
print(features_per_sec.shape)#use these features for mapping
print(features_per_sec)
print(labels.shape)
print(labels) #print raw token ids
print(features.shape)
print(features)#each row is frame
print(features[0].shape)
# Out:
# 366it [00:30, 11.84it/s]
# 49
# torch.Size([3655, 768])
# tensor([[ 0.0696,  0.2462,  0.1349,  ..., -0.0813,  0.1909,  0.6636],
#         [ 0.0677,  0.2605,  0.0886,  ..., -0.0841,  0.1483,  0.6823],
#         [ 0.0694,  0.2611,  0.0806,  ..., -0.0768,  0.1394,  0.6835],
#         ...,
#         [-0.0562, -0.3268,  0.2028,  ..., -0.1101,  0.1889, -0.1629],
#         [ 0.1319, -0.2553, -0.0234,  ...,  0.0813,  0.0953, -0.3228],
#         [ 0.1637, -0.3280, -0.0656,  ...,  0.0031,  0.0969, -0.0165]])
# torch.Size([181536])
# tensor([531, 531, 531,  ..., 531, 531,  72], device='cuda:0')
# torch.Size([181536, 768])
# tensor([[ 0.0450,  0.0229,  0.1287,  ..., -0.0172,  0.2426,  0.5934],
#         [ 0.0482,  0.0538,  0.1354,  ..., -0.0592,  0.2509,  0.5828],
#         [ 0.0633,  0.2322,  0.1627,  ..., -0.1425,  0.2460,  0.6410],
#         ...,
#         [ 0.1221,  0.2342,  0.1788,  ..., -0.1903,  0.2882,  0.6437],
#         [ 0.2168,  0.1204,  0.2047,  ..., -0.1619,  0.2731,  0.5740],
#         [ 0.2262,  0.0918,  0.1943,  ..., -0.1605,  0.2619,  0.5684]])
# torch.Size([768])

# %%
features_chunk = BEATs_model.extract_features(chunk)[0]
print(features_chunk.shape) #(batch size, num frames, frame dimension)
# Out:
# torch.Size([1, 496, 768])

# %%
from scipy.io import savemat

features_per_sec_mat = features_per_sec.cpu().numpy()
savemat("features_per_sec.mat", {"features_per_sec": features_per_sec_mat})
